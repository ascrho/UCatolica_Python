# %%
import parametros as p
import random

# NO MODIFICAR
class Rueda:
    def __init__(self):
        self.resistencia_actual = random.randint(*p.RESISTENCIA)
        self.resistencia_total = self.resistencia_actual
        self.estado = "Perfecto"

    def gastar(self, accion, tipo):
        if accion == "acelerar":
            if tipo == "automovil":
                self.resistencia_actual -= 5
            elif tipo == "moto":
                self.resistencia_actual -= 3
        elif accion == "frenar":
            if tipo == "automovil":
                self.resistencia_actual -= 10
            elif tipo == "moto":
                self.resistencia_actual -= 7
        self.actualizar_estado()

    def actualizar_estado(self):
        if self.resistencia_actual < 0:
            self.estado = "Rota"
        elif self.resistencia_actual < self.resistencia_total / 2:
            self.estado = "Gastada"
        elif self.resistencia_actual < self.resistencia_total:
            self.estado = "Usada"


# NO MODIFICAR
def seleccionar(vehiculos):
    if not len(vehiculos):
        print("No hay vehículos instanciados todavía")
        return

    print("Los vehículos disponibles son:")
    for indice in range(len(vehiculos)):
        print(f"[{indice}] {str(vehiculos[indice])}")

    elegido = int(input())
    while elegido < 0 or elegido >= len(vehiculos):
        print("intentelo de nuevo.")
        elegido = int(input())

    vehiculo = vehiculos[elegido]
    print("Se seleccionó el vehículo", str(vehiculo))
    return vehiculo

# %%
# Parte 1: Definición de clases

def avanzar(velocidad, tiempo):
    float(velocidad) #mt/seg
    int(tiempo) #seg

    kilometraje = velocidad*tiempo #mt
    return kilometraje

class Automovil():

    def __init__(self, kilometraje, ano):
        self.kilometraje = kilometraje #Km
        self.ano = ano
        self.ruedas = []
        for i in range(4):
            rueda=Rueda()
            self.ruedas.append(rueda)
        self.aceleracion = 0 #Km/Hr2
        self.velocidad = 0 #Km/Hr

    def avanzar(self,tiempo):
        int(tiempo)#seg
        VelocidadMS = (self.velocidad*1000)/3600 #Km/Hr -> mt/seg 
        self.kilometraje += (avanzar(tiempo,VelocidadMS))/1000 #mt -> Km

    def acelerar(self,tiempo):
        int(tiempo) #Hr
        self.aceleracion += tiempo*0.5 #K/Hr2 Incrementa la aceleracion del atributo de instancia aceleracion
        self.velocidad += self.aceleracion * tiempo * 3.6 #Km/Hr
        tiempo = (tiempo*3600) #Hr -> seg
        self.avanzar(tiempo) #Setea velocidad(mt/seg) e incrementa kilometraje(Km)
        #Ejecuta el metodo gastar a cada rueda
        for i in range(4):
            self.ruedas[i].gastar("acelerar","automovil")
        self.aceleracion = 0

    def frenar(self,tiempo):
        int(tiempo) #Hr
        self.aceleracion -= tiempo*0.5 #Km/Hr2 Reduce la aceleracion del atributo de instancia aceleracion
        self.velocidad += self.aceleracion * tiempo * 3.6 #Km/Hr
        #Si velocidad es negativa, entonces igualar a 0
        if (self.velocidad < 0):
            self.velocidad = 0
        #Convierte el tiempo ingresado en Hr en seg
        tiempo = (tiempo*3600) #Hr -> seg
        self.avanzar(tiempo) #Setea velocidad(mt/seg) e incrementa kilometraje(Km)
        #Ejecuta el metodo gastar a cada rueda
        for i in range(4):
            self.ruedas[i].gastar("frenar","automovil")
        self.aceleracion = 0

    def obtener_kilometraje(self):
        
        return self.kilometraje

    def reemplazar_rueda(self):
        #Crea una lista vacia
        resitencia = []
        #Inserta en la lista los valores de resitencia de cada una de las reudas
        for i in range(len(self.ruedas)):
            resitencia.append(self.ruedas[i].resistencia_actual)
        #Encuentra el valor de resistencia mas bajo, y retorna su indice
        rueda_gastada = resitencia.index(min(resitencia))
        #Elimina el indice determinado en el paso anterior
        del self.ruedas[rueda_gastada]
        #Crea un objeto rueda_repuesto de la clase Rueda
        rueda_repuesto=Rueda()
        #Inserta rueda_repuesto dentro de ruedas
        #self.ruedas.append(rueda_repuesto) #Inserta la rueda en la ultima posicion
        self.ruedas.insert(rueda_gastada,rueda_repuesto) #Inserta la rueda en el indice asociado a la rueda con la menor resistencia
        
    def __str__(self):
        return f"Automóvil del año {self.ano}"

class Moto():

    def __init__(self, kilometraje, ano, cilindrada):
        self.kilometraje = kilometraje #Km
        self.ano = ano
        self.ruedas = []
        for i in range(2):
            rueda=Rueda()
            self.ruedas.append(rueda)
        self.aceleracion = 0 #Km/h2
        self.velocidad = 0 #Km/h
        #Se usa el metodo val_neg, para evitar que se ingresen valores negativos
        self.cilindrada = self.val_neg(int(cilindrada))

    #Este metodo retorna el error definido en raise, si el valor que recibe es menor a 0
    def val_neg(self,cilindrada):
        if cilindrada < 0:
            raise ValueError("Cilindrada debe ser un valor mayor o igual a 0.")
        return cilindrada

    def avanzar(self,tiempo):
        int(tiempo)#seg
        VelocidadMS = (self.velocidad*1000)/3600 #Km/Hr -> mt/seg
        self.kilometraje += (avanzar(tiempo,VelocidadMS))/1000 #Km

    def acelerar(self,tiempo):
        int(tiempo) #Hr
        self.aceleracion += (tiempo*0.8) + (self.cilindrada*0.2) #Km/Hr2 Incrementa la aceleracion del atributo de instancia aceleracion
        self.velocidad += self.aceleracion * tiempo * 3 #Km/Hr
        #Convierte el tiempo ingresado en Hr en seg
        tiempo = (tiempo*3600) #Hr -> seg
        self.avanzar(tiempo) #Setea velocidad(mt/seg) e incrementa kilometraje(Km)
        #Ejecuta el metodo gastar a cada rueda
        for i in range(2):
            self.ruedas[i].gastar("acelerar","moto")
        self.aceleracion = 0

    def frenar(self,tiempo):
        int(tiempo) #seg
        tiempo = (tiempo/3600) #seg -> Hr
        self.aceleracion -= (tiempo*0.8) + (self.cilindrada*0.2) # Km/Hr2 Reduce la aceleracion del atributo de instancia aceleracion
        self.velocidad += self.aceleracion * tiempo * 3 #Km/Hr
        #Si velocidad es negativa, entonces igualar a 0
        if (self.velocidad < 0):
            self.velocidad = 0
        tiempo = (tiempo*3600) #Hr -> seg
        self.avanzar(tiempo) #Setea velocidad(mt/seg) e incrementa kilometraje(Km)
        #Ejecuta el metodo gastar a cada rueda
        for i in range(2):
            self.ruedas[i].gastar("frenar","moto")
        self.aceleracion = 0

    def obtener_kilometraje(self):
        return self.kilometraje

    def reemplazar_rueda(self):
        #Recorre las ruedas existentes
        for i in range(len(self.ruedas)):
            #Si alguna rueda tiene una resistencia actual menor a la mitad de la resistencia total
            if self.ruedas[i].resistencia_actual < self.ruedas[i].resistencia_total/2:
                #Encuentra la rueda y retorna su indice
                rueda_gastada = self.ruedas.index(self.ruedas[i])
                #Elimina de la lista el indice determinado en el paso anterior
                del self.ruedas[rueda_gastada]
                #Crea un objeto rueda_repuesto de la clase Rueda
                rueda_repuesto=Rueda()
                #Inserta rueda_repuesto dentro de ruedas
                #self.ruedas.append(rueda_repuesto) #Inserta la rueda en la ultima posicion
                self.ruedas.insert(rueda_gastada,rueda_repuesto) #Inserta la rueda en el indice asociado a la rueda con la menor resistencia

    def __str__(self):
        return f"Moto del año {self.ano}."

# Parte 2: Completar acciones
def accion(vehiculo, opcion):
    # Completar
    if opcion == 2:  # Acelerar
        print(str(vehiculo))
        tiempo = float(input("Indique el tiempo en Horas para acelerar el vehiculo:"))
        if str(vehiculo) == "Automóvil del año 2020":
            Automovil.acelerar(tiempo)
            print(f"Se ha acelerado por {tiempo} horas, llegando a una velocidad de {Automovil.velocidad} km/h.")
        elif vehiculo == "Moto":
            Moto.acelerar(tiempo)
            print(f"Se ha acelerado por {tiempo} horas, llegando a una velocidad de {Moto.velocidad} km/h.")
        else:
            print("Vehiculo no encontrado. Intente nuevamente.")

    elif opcion == 3:  # Frenar
        tiempo_frenar = float(input("Indique el tiempo en Horas para frenar el vehiculo:"))
        if vehiculo == "Automovil":
            Automovil.frenar(tiempo_frenar)
            print(f"Se ha frenado por {tiempo_frenar} horas, llegando a una velocidad de {Automovil.velocidad} km/h.")
        elif vehiculo == "Moto":
            Moto.frenar(tiempo_frenar)
            print(f"Se ha frenado por {tiempo_frenar} horas, llegando a una velocidad de {Moto.velocidad} km/h.")
        else:
            print("Vehiculo no encontrado. Intente nuevamente.")

    elif opcion == 4:  # Avanzar
        tiempo_avanzar = float(input("Indique el tiempo en Segundos para frenar el vehiculo:"))
        if vehiculo == "Automovil":
            Automovil.avanzar(tiempo_avanzar)
            print(f"Se ha avanzado por {tiempo_avanzar} segundos, llegando a una velocidad de {Automovil.velocidad} km/h.")
        elif vehiculo == "Moto":
            Moto.avanzar(tiempo_avanzar)
            print(f"Se ha avanzado por {tiempo_avanzar} segundos, llegando a una velocidad de {Moto.velocidad} km/h.")
        else:
            print("Vehiculo no encontrado. Intente nuevamente.")

    elif opcion == 5:  # Cambiar rueda
        if vehiculo == "Automovil":
            Automovil.reemplazar_rueda()
            print("Se han reemplazado las ruedas con éxito")
        elif vehiculo == "Moto":
            Moto.reemplazar_rueda()
            print("Se han reemplazado las ruedas con éxito")
        else:
            print("Vehiculo no encontrado. Intente nuevamente.")

    elif opcion == 6:  # Mostrar Estado
        if vehiculo == "Automovil":
            print(f"El año del vehiculo es {Automovil.anno}, se encuentra actualmente desplazandose a una velocidad de {Automovil.velocidad} km/h con un kilometraje de {Automovil.obtener_kilometraje} Km.")
            print(f"El estado actual de la Rueda 1 es: {Automovil.ruedas[0].resistencia_actual}")
            print(f"El estado actual de la Rueda 2 es: {Automovil.ruedas[1].resistencia_actual}")
            print(f"El estado actual de la Rueda 3 es: {Automovil.ruedas[2].resistencia_actual}")
            print(f"El estado actual de la Rueda 4 es: {Automovil.ruedas[3].resistencia_actual}")
        elif vehiculo == "Moto":
            print(f"El año de la moto es {Moto.anno}, se encuentra actualmente desplazandose a una velocidad de {Moto.velocidad} km/h con un kilometraje de {Moto.obtener_kilometraje} Km.")
            print(f"El estado actual de la Rueda 1 es: {Moto.ruedas[0].resistencia_actual}")
            print(f"El estado actual de la Rueda 2 es: {Moto.ruedas[1].resistencia_actual}")
        else:
            print("Vehiculo no encontrado. Intente nuevamente.")

# %%
auto1=Automovil(10,2025)
moto1=Moto(10,2025,5)
print(auto1.velocidad)
print(auto1.kilometraje)
auto1.acelerar(1)
moto1.acelerar(1)
print(auto1.velocidad)
print(auto1.kilometraje)

vehiculos = []
vehiculo = Automovil(100,2020)
vehiculos.append(vehiculo)
print(str(vehiculos[0])+".")
print("Automovil" in str(type(vehiculo)))

print()
auto1.avanzar(50)
print(auto1.kilometraje)

print()
print(auto1.obtener_kilometraje())
#Sin los parentesis no retorna el valor, retorna <bound method Moto.obtener_kilometraje of <__main__.Moto object at 0x000001C239BC8DD0>>
print(moto1.obtener_kilometraje)

# %%
#PRUEBAS CLASE MOTO

moto1 = Moto(10,2020,1)
print(moto1.cilindrada)

print("resistencia_total")
print(moto1.ruedas[0].resistencia_total)
print(moto1.ruedas[1].resistencia_total)

print()
moto1.acelerar(15)
moto1.acelerar(20)
moto1.acelerar(30)
moto1.frenar(15)
moto1.frenar(20)
moto1.frenar(30)
moto1.frenar(15)
moto1.frenar(20)
moto1.frenar(30)
print("resistencia_actual")
print(moto1.ruedas[0].resistencia_actual)
print(moto1.ruedas[1].resistencia_actual)
print(moto1.ruedas[0].resistencia_total/2)
print(moto1.ruedas[1].resistencia_total/2)

print()
moto1.reemplazar_rueda()
print("reemplazar_rueda")
print(moto1.ruedas[0].resistencia_total)
print(moto1.ruedas[1].resistencia_total)

# %%
#PRUEBAS CLASE AUTOMOVIL
auto1 = Automovil(10,2020)
print(auto1)
auto1.avanzar(15)
print(auto1.kilometraje)
print(auto1.velocidad)

auto1.ruedas[0].resistencia_actual = 20
auto1.ruedas[1].resistencia_actual = 20
auto1.ruedas[2].resistencia_actual = 40
auto1.ruedas[3].resistencia_actual = 50

print()
print("Ruedas al inicio")
print(auto1.ruedas[0].resistencia_actual)
print(auto1.ruedas[1].resistencia_actual)
print(auto1.ruedas[2].resistencia_actual)
print(auto1.ruedas[3].resistencia_actual)
print()
print("Ruedas al gastar")
auto1.acelerar(15)
print(auto1.ruedas[0].resistencia_actual)
print(auto1.ruedas[1].resistencia_actual)
print(auto1.ruedas[2].resistencia_actual)
print(auto1.ruedas[3].resistencia_actual)

print()
resitencia = list()
for i in range(len(auto1.ruedas)):
    resitencia.append(auto1.ruedas[i].resistencia_actual)

for i in range(len(resitencia)):
    print(i,resitencia[i])

rueda_repuesto=Rueda()
#resitencia = [50 if x==minres else x for x in resitencia]
minresv = min(resitencia)
rueda_gastada = resitencia.index(min(resitencia))
print(minresv)
print(rueda_gastada)
del auto1.ruedas[rueda_gastada]
auto1.ruedas.insert(rueda_gastada,rueda_repuesto)
print("Ruedas al reemplazar")
print(auto1.ruedas[0].resistencia_actual)
print(auto1.ruedas[1].resistencia_actual)
print(auto1.ruedas[2].resistencia_actual)
print(auto1.ruedas[3].resistencia_actual)

print()
a=[1,2,3,1,3,2,1,1]
print(a)
print([4 if x==1 else x for x in a])
print(a)

'''
print()
auto1.reemplazar_rueda()
print(auto1.ruedas[0].resistencia_actual)
print(auto1.ruedas[1].resistencia_actual)
print(auto1.ruedas[2].resistencia_actual)
print(auto1.ruedas[3].resistencia_actual)
'''
# Out:
# Automóvil del año 2020
# 10.0
# 0
#
# Ruedas al inicio
# 20
# 20
# 40
# 50
#
# Ruedas al gastar
# 15
# 15
# 35
# 45
#
# 0 15
# 1 15
# 2 35
# 3 45
# 15
# 0
# Ruedas al reemplazar
# 96
# 15
# 35
# 45
#
# [1, 2, 3, 1, 3, 2, 1, 1]
# [4, 2, 3, 4, 3, 2, 4, 4]
# [1, 2, 3, 1, 3, 2, 1, 1]
# '\nprint()\nauto1.reemplazar_rueda()\nprint(auto1.ruedas[0].resistencia_actual)\nprint(auto1.ruedas[1].resistencia_actual)\nprint(auto1.ruedas[2].resistencia_actual)\nprint(auto1.ruedas[3].resistencia_actual)\n'

# %%
resitencia = []
#Inserta en la lista los valores de resitencia de cada una de las reudas
for i in range(len(self.ruedas)):
    resitencia.append(self.ruedas[i].resistencia_actual)
#Encuentra el valor de resistencia mas bajo, y retorna su indice
rueda_gastada = resitencia.index(min(resitencia))
#Elimina el indice determinado en el paso anterior
del self.ruedas[rueda_gastada]
#Crea un objeto rueda_repuesto de la clase Rueda
rueda_repuesto=Rueda()
#Inserta rueda_repuesto dentro de ruedas
self.ruedas.append(rueda_repuesto)

# %%
def prueba(numero):
    if numero == 0:
        print("El numero es cero")
    elif numero==1:
        print("El numero es uno")
    elif numero==2:
        print("El numero es 2")
    elif numero=="Prueba":
        print("El numero es Prueba")

prueba("Prueba")
